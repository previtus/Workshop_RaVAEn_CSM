# %% [markdown]
# # Workshop - Testing the accounts and libraries before the workshop
#
# This notebook tests your Google Earth Engine account.

# %% [markdown]
# ## Google Earth Engine
#
# First register your Google account with Google Earth Engine (**important: use the same Google account throughout this notebook** - the same one you are currently connected under in Google Colab and also the same one you will use with Google Drive below).
#
# Creating the GEE account is free, but it needs activation at https://earthengine.google.com/signup/ before the class. Note that the sign-up form needs to be filled with relevant information and it can also be denied (if the information is too short for example), please use the following answers:
#
# > *Affiliation/Institution:* Workshop at Central St Martins
#
# > *Institution type:* Other
#
# > *Other institution type:* Student Workshop
#
# > *What would you like to accomplish with Earth Engine:* For demonstration of Unsupervised Machine Learning algorithms on Remote Sensing data. Primarily testing the "Unsupervised Change Detection of Extreme Events Using ML On-Board" paper of https://arxiv.org/abs/2111.02995.

# %% [markdown]
# After activating your account try running the next field.
#
# You might need to create a new project under your account and to agree to Google terms.
#
# In the end you should be able to generate a token and paste it here. If you end up with the ```Successfully saved authorization token.``` message, it's set up correctly.

# %%
# Test your account in Google Earth Engine
# !earthengine authenticate

# %% [markdown]
# ## Google Drive
#
# This part is easier, only make sure you are still using the same Google Account as the one previously registered with GEE.

# %%
# Test connection to the Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# If the following command lists files from your Google Drive, then it's all set up correctly.

# %%
# !ls /content/drive/MyDrive/ -luah
